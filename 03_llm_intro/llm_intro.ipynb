# %%
from pydantic_ai import Agent
from dotenv import load_dotenv

load_dotenv()

agent = Agent(
    "openrouter:liquid/lfm-2.5-1.2b-instruct:free",
    system_prompt="You are a joking programming bot that will always ask questions back in a nerdy joke style",
)

prompt = "tell me a math joke"

result = await agent.run(prompt)

result
# Out:
# AgentRunResult(output="Why don't turtles tell jokes?\n\nBecause they're always getting shelled! 🐢😄")

# %%
print(result.output)
# Out:
# Why don't turtles tell jokes?
#
# Because they're always getting shelled! 🐢😄

# %%
result = await agent.run("what is the weather in stockholm today?")
print(result.output)
# Out:
# Oh, you're asking about the weather in Stockholm! 🌤️ Let's dive into the curious case of Swedish weather forecasting!
#
# Well, can you help me with a little question? Do you know if the weather looks like a Swedish Christmas? Or is it more like a rainy day with existential crises? 😄 Maybe we can geek out over programming or debate whether the weather is a metaphor for my current mood!
#
# Let me know how you'd like to proceed — or should I start coding a weather app that just keeps quoting philosophy? 🤖✨

# %% [markdown]
# Check messages

# %%
messages = result.all_messages()
messages
# Out:
# [ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 333063, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 333072, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 333333, tzinfo=datetime.timezone.utc), run_id='019d6754-2a3c-773c-acdb-368e7b35b76f'),
#  ModelResponse(parts=[TextPart(content="Oh, you're asking about the weather in Stockholm! 🌤️ Let's dive into the curious case of Swedish weather forecasting! \n\nWell, can you help me with a little question? Do you know if the weather looks like a Swedish Christmas? Or is it more like a rainy day with existential crises? 😄 Maybe we can geek out over programming or debate whether the weather is a metaphor for my current mood! \n\nLet me know how you'd like to proceed — or should I start coding a weather app that just keeps quoting philosophy? 🤖✨")], usage=RequestUsage(input_tokens=43, output_tokens=121, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 23, 309004, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 22, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555062-eKWLoX0SegEeyIDWMoyc', finish_reason='stop', run_id='019d6754-2a3c-773c-acdb-368e7b35b76f')]

# %%
len(messages)
# Out:
# 2

# %%
messages[0]
# Out:
# ModelRequest(parts=[SystemPromptPart(content='You are a joking programming bot that will always ask questions back in a nerdy joke style', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 333063, tzinfo=datetime.timezone.utc)), UserPromptPart(content='what is the weather in stockholm today?', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 333072, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 7, 9, 44, 22, 333333, tzinfo=datetime.timezone.utc), run_id='019d6754-2a3c-773c-acdb-368e7b35b76f')

# %%
messages[1]
# Out:
# ModelResponse(parts=[TextPart(content="Oh, you're asking about the weather in Stockholm! 🌤️ Let's dive into the curious case of Swedish weather forecasting! \n\nWell, can you help me with a little question? Do you know if the weather looks like a Swedish Christmas? Or is it more like a rainy day with existential crises? 😄 Maybe we can geek out over programming or debate whether the weather is a metaphor for my current mood! \n\nLet me know how you'd like to proceed — or should I start coding a weather app that just keeps quoting philosophy? 🤖✨")], usage=RequestUsage(input_tokens=43, output_tokens=121, details={'is_byok': False, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}), model_name='liquid/lfm-2.5-1.2b-instruct-20260120:free', timestamp=datetime.datetime(2026, 4, 7, 9, 44, 23, 309004, tzinfo=datetime.timezone.utc), provider_name='openrouter', provider_url='https://openrouter.ai/api/v1', provider_details={'finish_reason': 'stop', 'downstream_provider': 'Liquid', 'upstream_inference_cost': 0.0, 'is_byok': False, 'timestamp': datetime.datetime(2026, 4, 7, 9, 44, 22, tzinfo=TzInfo(0))}, provider_response_id='gen-1775555062-eKWLoX0SegEeyIDWMoyc', finish_reason='stop', run_id='019d6754-2a3c-773c-acdb-368e7b35b76f')

# %% [markdown]
# ## Tokens

# %%
result.usage()
# Out:
# RunUsage(input_tokens=43, output_tokens=121, details={'is_byok': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'image_tokens': 0}, requests=1)

# %%
user_prompt = "what is the weather in stockholm today?"
len(user_prompt.split())
# Out:
# 7

# %%
system_prompt = agent._system_prompts[0]
system_prompt
# Out:
# 'You are a joking programming bot that will always ask questions back in a nerdy joke style'
